# %% [markdown]
# # QuTiP example: Energy-levels of a quantum systems as a function of a single parameter

# %% [markdown]
# J.R. Johansson and P.D. Nation
#
# For more information about QuTiP see [http://qutip.org](http://qutip.org)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import numpy as np
from numpy import pi

# %%
from qutip import *

# %% [markdown]
# ## Energy spectrum of three coupled qubits

# %%
# def compute(w1list, w2, w3, g12, g13):

#     # Pre-compute operators for the hamiltonian
#     sz1 = tensor(sigmaz(), qeye(2), qeye(2))
#     sx1 = tensor(sigmax(), qeye(2), qeye(2))

#     sz2 = tensor(qeye(2), sigmaz(), qeye(2))
#     sx2 = tensor(qeye(2), sigmax(), qeye(2))

#     sz3 = tensor(qeye(2), qeye(2), sigmaz())
#     sx3 = tensor(qeye(2), qeye(2), sigmax())
  
#     idx = 0
#     evals_mat = np.zeros((len(w1list),2*2*2))
#     for w1 in w1list:

#         # evaluate the Hamiltonian
#         H = w1 * sz1 + w2 * sz2 + w3 * sz3 + g12 * sx1 * sx2 + g13 * sx1 * sx3

#         # find the energy eigenvalues of the composite system
#         evals, ekets = H.eigenstates()

#         evals_mat[idx,:] = np.real(evals)

#         idx += 1

#     return evals_mat

# %%
def compute(w1list, w2, w3, g12, g13):

    # Pre-compute operators for the hamiltonian
    sz1 = tensor(sigmaz(), qeye(2), qeye(2))
    sx1 = tensor(sigmax(), qeye(2), qeye(2))

    sz2 = tensor(qeye(2), sigmaz(), qeye(2))
    sx2 = tensor(qeye(2), sigmax(), qeye(2))

    sz3 = tensor(qeye(2), qeye(2), sigmaz())
    sx3 = tensor(qeye(2), qeye(2), sigmax())
  
    evals_mat = np.zeros((len(w1list),2*2*2))
    for i, wi in enumerate(w1list):

        # evaluate the Hamiltonian
        H = wi * sz1 + w2 * sz2 + w3 * sz3 + g12 * sx1 * sx2 + g13 * sx1 * sx3

        # find the energy eigenvalues of the composite system
        evals, ekets = H.eigenstates()

        evals_mat[i,:] = np.real(evals)

    return evals_mat

# %%
w1  = 1.0 * 2 * pi   # atom 1 frequency: sweep this one
w2  = 0.9 * 2 * pi   # atom 2 frequency
w3  = 1.1 * 2 * pi   # atom 3 frequency
g12 = 0.05 * 2 * pi   # atom1-atom2 coupling strength
g13 = 0.05 * 2 * pi   # atom1-atom3 coupling strength

w1list = np.linspace(0.5, 1.5, 50) * 2 * pi # atom 1 frequency range

# %%
evals_mat = compute(w1list, w2, w3, g12, g13)

# %%
fig, ax = plt.subplots(figsize=(12,6))

for n in [1,2,3]:
    ax.plot(w1list / (2*pi), (evals_mat[:,n]-evals_mat[:,0]) / (2*pi), 'b')

ax.set_xlabel('Energy splitting of atom 1')
ax.set_ylabel('Eigenenergies')
ax.set_title('Energy spectrum of three coupled qubits');

# %% [markdown]
# ## Versions

# %%
from qutip.ipynbtools import version_table

version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>QuTiP</td><td>5.0.4</td></tr><tr><td>Numpy</td><td>2.0.2</td></tr><tr><td>SciPy</td><td>1.13.1</td></tr><tr><td>matplotlib</td><td>3.9.4</td></tr><tr><td>Number of CPUs</td><td>16</td></tr><tr><td>BLAS Info</td><td>Generic</td></tr><tr><td>IPython</td><td>8.18.1</td></tr><tr><td>Python</td><td>3.9.21 (main, Dec  4 2024, 08:53:34)
# [GCC 9.4.0]</td></tr><tr><td>OS</td><td>posix [linux]</td></tr><tr><td colspan='2'>Wed Jan 15 15:31:18 2025 IST</td></tr></table>
